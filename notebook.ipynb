# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/Marchisceddu/finestSAM/blob/main/notebook.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import os
import sys
import shutil

# Environment detection
try:
    import google.colab
    IS_COLAB = True
except ImportError:
    IS_COLAB = False

if IS_COLAB:
    BASE_PATH = "/content"
    
    # Install dependencies
    # %pip install -q Lightning segmentation_models_pytorch wget

    # Clone repository
    repo_name = "MSSegSAM"
    repo_url = "https://Marchisceddu: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@github.com/WholeNow/MSSegSAM.git"
    repo_path = os.path.join(BASE_PATH, repo_name)

    if not os.path.exists(repo_path):
        # !git clone {repo_url}
else:
    BASE_PATH = os.getcwd()

import wget

# Checkpoint verification
CHECKPOINT_DIR = os.path.join(BASE_PATH, "MSSegSAM", "finestSAM", "sav")
CHECKPOINT_URL = "https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth"
CHECKPOINT_PATH = os.path.join(CHECKPOINT_DIR, "sam_vit_b_01ec64.pth")

os.makedirs(CHECKPOINT_DIR, exist_ok=True)

if not os.path.exists(CHECKPOINT_PATH):
    wget.download(CHECKPOINT_URL, out=CHECKPOINT_DIR)

print(f"Environment initialized in: {BASE_PATH}")

# Path definitions
DATA_PREP_DIR = os.path.join(BASE_PATH, "prep_data")
MODEL_DIR = os.path.join(BASE_PATH, "MSSegSAM")
RAW_DATA_DIR = os.path.join(DATA_PREP_DIR, "Datasets_raw")
OUTPUT_COCO_DIR = os.path.join(DATA_PREP_DIR, "Datasets_COCO")

print(f"Data Prep Directory: {DATA_PREP_DIR}")
print(f"Raw Data Directory:  {RAW_DATA_DIR}")
print(f"Output Directory:    {OUTPUT_COCO_DIR}")

# %%
# Configuration
SCRIPT_PATH = os.path.join(DATA_PREP_DIR, "create_dataset.py")
DATASET_IDS = "0"
MODALITY = "T1"
SLICE_RANGE = "0 181"
REMOVE_EMPTY_SLICES = True

# Execution logic
if os.path.exists(SCRIPT_PATH):
    flag_empty = "--remove_empty" if REMOVE_EMPTY_SLICES else ""
    
    # !python "{SCRIPT_PATH}" \
        --input_dir "{RAW_DATA_DIR}" \
        --output_dir "{OUTPUT_COCO_DIR}" \
        --dataset_ids {DATASET_IDS} \
        --modality {MODALITY} \
        --slice_range {SLICE_RANGE} \
        {flag_empty}
else:
    print(f"Error: create_dataset.py not found in {DATA_PREP_DIR}")

# %%
# Switch to model directory
os.chdir(MODEL_DIR)

print(f"Starting training...")
print(f"Target Dataset: {OUTPUT_COCO_DIR}")

# Train
# %run finestSAM/__main__.py --mode train --dataset "{OUTPUT_COCO_DIR}"

# Return to base directory
os.chdir(BASE_PATH)
